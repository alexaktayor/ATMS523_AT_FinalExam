# %%
import pandas as pd, numpy as np
from pathlib import Path
import fsspec

S3_STATIONS_TXT   = "s3://noaa-ghcn-pds/ghcnd-stations.txt"
S3_INVENTORY_TXT  = "s3://noaa-ghcn-pds/ghcnd-inventory.txt"
S3_BY_STATION     = "s3://noaa-ghcn-pds/csv/by_station/{id}.csv"
STOR = {"anon": True}

OUTDIR = Path('../data'); OUTDIR.mkdir(parents=True, exist_ok=True)
OUT_PARQUET = OUTDIR / 'ghcn_il_top4_daily.parquet'
print('Output:', OUT_PARQUET.resolve())
# Out:
# Output: /home/alexakt2/.jupyter/https:/data/ghcn_il_top4_daily.parquet

# %%
# Load Stations
colspecs = [(0,11),(12,20),(21,30),(31,37),(38,40),(41,71),(72,75),(76,79),(80,85)]
names = ['ID','LATITUDE','LONGITUDE','ELEVATION','STATE','NAME','GSN_FLAG','HCN_CRN_FLAG','WMO_ID']

stations = pd.read_fwf(S3_STATIONS_TXT, colspecs=colspecs, names=names, dtype={'ID':str,'STATE':str,'WMO_ID':str}, storage_options=STOR)
stations['NAME'] = stations['NAME'].str.strip(); stations['STATE'] = stations['STATE'].fillna('').str.strip()

inventory = pd.read_csv(
    S3_INVENTORY_TXT, sep=r'\s+', names=['ID','LAT','LON','ELEMENT','FIRSTYEAR','LASTYEAR'],
    dtype={'ID':str,'ELEMENT':str,'FIRSTYEAR':int,'LASTYEAR':int}, engine='python', storage_options=STOR
)

stations.head(), inventory.head()
# Out:
# (            ID  LATITUDE  LONGITUDE  ELEVATION STATE                   NAME  \
#  0  ACW00011604   17.1167   -61.7833       10.1        ST JOHNS COOLIDGE FLD
#  1  ACW00011647   17.1333   -61.7833       19.2                     ST JOHNS
#  2  AE000041196   25.3330    55.5170       34.0          SHARJAH INTER. AIRP
#  3  AEM00041194   25.2550    55.3640       10.4                   DUBAI INTL
#  4  AEM00041217   24.4330    54.6510       26.8               ABU DHABI INTL
#
#    GSN_FLAG HCN_CRN_FLAG WMO_ID
#  0      NaN          NaN    NaN
#  1      NaN          NaN    NaN
#  2      GSN          NaN  41196
#  3      NaN          NaN  41194
#  4      NaN          NaN  41217  ,
#              ID      LAT      LON ELEMENT  FIRSTYEAR  LASTYEAR
#  0  ACW00011604  17.1167 -61.7833    TMAX       1949      1949
#  1  ACW00011604  17.1167 -61.7833    TMIN       1949      1949
#  2  ACW00011604  17.1167 -61.7833    PRCP       1949      1949
#  3  ACW00011604  17.1167 -61.7833    SNOW       1949      1949
#  4  ACW00011604  17.1167 -61.7833    SNWD       1949      1949)

# %%
# Load Station: USC00087205
def load_station_daily(url: str) -> pd.DataFrame:
    df = pd.read_csv(url, storage_options=STOR, dtype={'ID':str,'ELEMENT':str}, parse_dates=['DATE'])
    df['DATA_VALUE'] = df['DATA_VALUE'].replace(-9999, np.nan)
    wide = (df.pivot_table(index=['ID','DATE'], columns='ELEMENT', values='DATA_VALUE', aggfunc='first').reset_index())
    for c in ('TMAX','TMIN','TAVG'):
        if c in wide: wide[c] = wide[c]/10.0
    if 'PRCP' in wide: wide['PRCP'] = wide['PRCP']/10.0
    return wide.sort_values(['ID','DATE']).reset_index(drop=True)

dt_daily = load_station_daily(S3_BY_STATION.format(id='USC00087205'))
dt_daily.tail()
# Out:
# /tmp/ipykernel_18404/1077117106.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url, storage_options=STOR, dtype={'ID':str,'ELEMENT':str}, parse_dates=['DATE'])
# ELEMENT           ID       DATE  DAPR  MDPR  PRCP  SNOW  SNWD  TMAX  TMIN  \
# 46156    USC00087205 2025-12-05   NaN   NaN   0.0   NaN   NaN  29.4  17.8
# 46157    USC00087205 2025-12-06   NaN   NaN   0.0   NaN   NaN  28.3  20.6
# 46158    USC00087205 2025-12-07   NaN   NaN  18.5   NaN   NaN  28.3  15.6
# 46159    USC00087205 2025-12-08   NaN   NaN  40.6   NaN   NaN  24.4  17.2
# 46160    USC00087205 2025-12-09   NaN   NaN   0.3   NaN   NaN  23.9  10.6
#
# ELEMENT   TOBS  WT01  WT03  WT04  WT06  WT08  WT11  WT14  WT16
# 46156    278.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46157    278.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46158    217.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46159    239.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46160    200.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
#1 

# Remove data that's not within 1991 and 2020

dt_daily_30yrs = dt_daily.loc[dt_daily['DATE'].between('1991-01-01', '2020-12-31')].copy()

# %%
# Check if there are NaNs

print(dt_daily_30yrs['TMAX'].isnull().sum()) 
print(dt_daily_30yrs['TMIN'].isnull().sum()) 

# Drop NaNs
dt_daily_30yrs = dt_daily_30yrs.dropna(subset=['TMAX'])

dt_daily_30yrs = dt_daily_30yrs.dropna(subset=['TMIN'])
# Out:
# 142
# 159

# %%
# Get Year and Month from DATE Column

dt_daily_30yrs['DATE'] = pd.to_datetime(dt_daily_30yrs['DATE'])
dt_daily_30yrs['year'] = dt_daily_30yrs['DATE'].dt.year
dt_daily_30yrs['month'] = dt_daily_30yrs['DATE'].dt.month

# Get only the data from strawberry season
dt_straw = dt_daily_30yrs[dt_daily_30yrs['month'].isin([1, 10, 11, 12])]

# %%
# Risk Mean

frost_days = (dt_straw['TMIN'] <=32).sum()
freeze_days = (dt_straw['TMIN'] <=28).sum()

# 4 months of the year for 30 years
months = (30)*4

# Frost - Risk Mean 
rm_frost = frost_days/months
print(rm_frost)

# Freeze - Risk Mean
rm_freeze = freeze_days/months
print(rm_freeze)
# Out:
# 30.091666666666665
# 30.091666666666665

# %%
# I am getting the same value for both which seems wrong... I am going to move on in the intrest of time and maybe come back

# %%
#2

# load file data
url = "https://www.cpc.ncep.noaa.gov/data/indices/sstoi.indices"

ds = pd.read_csv(url, delim_whitespace=True, comment='#', header=None)

ds.columns = ["YR","MON","NINO1+2","ANOM1","NINO3","ANOM2","NINO3.4","ANOM3","NINO4","ANOM4"]
# Out:
# /tmp/ipykernel_18404/1811308429.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   ds = pd.read_csv(url, delim_whitespace=True, comment='#', header=None)

# %%
# Update to strawberry season
ds['DATE'] = pd.to_datetime(dict(year=ds['YR'], month=ds['MON'], day=1))
ds_straw = ds['time'].dt.month.isin([10,11,12,1])

# moving on because of time. I am not going to seperate this out into months to make it easier
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2407, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "YR"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 2
#       1 # Update to strawberry season
# ----> 2 ds['DATE'] = pd.to_datetime(dict(year=ds['YR'], month=ds['MON'], day=1))
#       3 ds_straw = ds['time'].dt.month.isin([10,11,12,1])
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/tools/datetimes.py:1075, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1075     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1076 elif isinstance(arg, Index):
#    1077     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/tools/datetimes.py:1214, in _assemble_from_unit_mappings(arg, errors, utc)
#    1210         values = values.astype("int64", copy=False)
#    1211     return values
#    1213 values = (
# -> 1214     coerce(arg[unit_rev["year"]]) * 10000
#    1215     + coerce(arg[unit_rev["month"]]) * 100
#    1216     + coerce(arg[unit_rev["day"]])
#    1217 )
#    1218 try:
#    1219     values = to_datetime(values, format="%Y%m%d", errors=errors, utc=utc)
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/tools/datetimes.py:1206, in _assemble_from_unit_mappings.<locals>.coerce(values)
#    1204 def coerce(values):
#    1205     # we allow coercion to if errors allows
# -> 1206     values = to_numeric(values, errors=errors)
#    1208     # prevent overflow in case of int8 or int16
#    1209     if is_integer_dtype(values.dtype):
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/tools/numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233 coerce_numeric = errors not in ("ignore", "raise")
#     234 try:
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
#     237         set(),
#     238         coerce_numeric=coerce_numeric,
#     239         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     240         or isinstance(values_dtype, StringDtype)
#     241         and values_dtype.na_value is libmissing.NA,
#     242     )
#     243 except (ValueError, TypeError):
#     244     if errors == "raise":
#
# File pandas/_libs/lib.pyx:2449, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "YR" at position 0

# %%
nino_yr = ds.groupby("YR").mean().reset_index()
nino_yr.head()

freeze_data = dt_straw[dt_straw['TMIN'] <= 28].copy()
freeze_yearly = freeze_data.groupby(freeze_data['DATE'].dt.year).size().reset_index(name='freeze_days')
freeze_yearly.rename(columns={'DATE': 'YR'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2460, in GroupBy.mean.<locals>.<lambda>(x)
#    2457 else:
#    2458     result = self._cython_agg_general(
#    2459         "mean",
# -> 2460         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2461         numeric_only=numeric_only,
#    2462     )
#    2463     return result.__finalize__(self.obj, method="groupby")
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)   6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
#   12440         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12441     )
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string '123456789101112' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 nino_yr = ds.groupby("YR").mean().reset_index()
#       2 nino_yr.head()
#       4 freeze_data = dt_straw[dt_straw['TMIN'] <= 28].copy()
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2458, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2451     return self._numba_agg_general(
#    2452         grouped_mean,
#    2453         executor.float_dtype_mapping,
#    2454         engine_kwargs,
#    2455         min_periods=0,
#    2456     )
#    2457 else:
# -> 2458     result = self._cython_agg_general(
#    2459         "mean",
#    2460         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2461         numeric_only=numeric_only,
#    2462     )
#    2463     return result.__finalize__(self.obj, method="groupby")
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2004, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2001     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002     return result
# -> 2004 new_mgr = data.grouped_reduce(array_func)
#    2005 res = self._wrap_agged_manager(new_mgr)
#    2006 if how in ["idxmin", "idxmax"]:
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/internals/managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/internals/blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2001, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1998     return result
#    2000 assert alt is not None
# -> 2001 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2002 return result
#
# File ~/envs/xarray-climate/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1947, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1945     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1946     # preserve the kind of exception that raised
# -> 1947     raise type(err)(msg) from err
#    1949 dtype = ser.dtype
#    1950 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
df_corr = pd.merge(freeze_yearly, nino_yr, on='YR', how='inner')
df_corr.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df_corr = pd.merge(freeze_yearly, nino_yr, on='YR', how='inner')
#       2 df_corr.head()
#
# NameError: name 'freeze_yearly' is not defined

# %%
from scipy.stats import pearsonr

for col in ["NINO1+2","NINO3","NINO3.4","NINO4"]:
    r, p = pearsonr(df_corr['freeze_days'], df_corr[col])
    print(f"{col}: r = {r:.3f}, p = {p:.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 4
#       1 from scipy.stats import pearsonr
#       3 for col in ["NINO1+2","NINO3","NINO3.4","NINO4"]:
# ----> 4     r, p = pearsonr(df_corr['freeze_days'], df_corr[col])
#       5     print(f"{col}: r = {r:.3f}, p = {p:.3f}")
#
# NameError: name 'df_corr' is not defined

# %%
# I have run out of time and cannot get this to run. If I could see the results then I would see which has the value
# closest to one and that would have the strongest correlation
